# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [spotipy]
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="7f306bfa44c64bef8f1fd5f86e5a4b8d", client_secret="6095b2c1d02c4f75ba66f95f22f97ee1")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlisy_URI = playlist_link.split("/")[-1].split("?")[0]

# %%
playlisy_URI1 = "3cEYpjA9oz9GiPac4AsH4n"

# %%
playlisy_URI1
# Out:
# '3cEYpjA9oz9GiPac4AsH4n'

# %%
data = sp.playlist_tracks(playlisy_URI1)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '2pANdqPvxInB0YvcDiw4ko'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Progressive Psy Trance Picks Vol.8'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2012-04-02'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 20

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2pANdqPvxInB0YvcDiw4ko'

# %%
data['items']
# Out:
# [{'added_at': '2015-01-15T12:39:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jmperezperez'},
#    'href': 'https://api.spotify.com/v1/users/jmperezperez',
#    'id': 'jmperezperez',
#    'type': 'user',
#    'uri': 'spotify:user:jmperezperez'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {"album_id" : album_id, "album_name": album_name, "album_release_date" : album_release_date, 
    "album_total_tracks":album_total_tracks,"album_url":album_url}
    
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '2pANdqPvxInB0YvcDiw4ko',
#   'album_name': 'Progressive Psy Trance Picks Vol.8',
#   'album_release_date': '2012-04-02',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/2pANdqPvxInB0YvcDiw4ko'},
#  {'album_id': '6nlfkk5GoXRL1nktlATNsy',
#   'album_name': 'Wellness & Dreaming Source',
#   'album_release_date': '2015-01-09',
#   'album_total_tracks': 25,
#   'album_url': 'https://open.spotify.com/album/6nlfkk5GoXRL1nktlATNsy'},
#  {'album_id': '4hnqM0JK4CM1phwfq1Ldyz',
#   'album_name': 'This Is Happening',
#   'album_release_date': '2010-05-17',
#   'album_total_tracks': 9,
#   'album_url': 'https://open.spotify.com/album/4hnqM0JK4CM1phwfq1Ldyz'},
#  {'album_id': '2usKFntxa98WHMcyW6xJBz',
#   'album_name': 'Glenn Horiuchi Trio / Gelenn Horiuchi Quartet: Mercy / Jump Start / Endpoints / Curl Out / Earthworks / Mind Probe / Null Set / Another Space (A)',
#   'album_release_date': '2011-04-01',
#   'album_total_tracks': 8,
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/066X20Nz7iquqkkCW6Jxy6'},
#   'href': 'https://api.spotify.com/v1/artists/066X20Nz7iquqkkCW6Jxy6',
#   'id': '066X20Nz7iquqkkCW6Jxy6',
#   'name': 'LCD Soundsystem',
#   'type': 'artist',
#   'uri': 'spotify:artist:066X20Nz7iquqkkCW6Jxy6'}]

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
               artist_dict = {"artist_id":artist["id"], "artist_name":artist["name"],"external_url":artist["href"]}
            artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6eSdhw46riw2OUHgMwR8B5',
#   'artist_name': 'Odiseo',
#   'external_url': 'https://api.spotify.com/v1/artists/6eSdhw46riw2OUHgMwR8B5'},
#  {'artist_id': '5VQE4WOzPu9h3HnGLuBoA6',
#   'artist_name': 'Vlasta Marek',
#   'external_url': 'https://api.spotify.com/v1/artists/5VQE4WOzPu9h3HnGLuBoA6'},
#  {'artist_id': '066X20Nz7iquqkkCW6Jxy6',
#   'artist_name': 'LCD Soundsystem',
#   'external_url': 'https://api.spotify.com/v1/artists/066X20Nz7iquqkkCW6Jxy6'},
#  {'artist_id': '272ArH9SUAlslQqsSgPJA2',
#   'artist_name': 'Glenn Horiuchi Trio',
#   'external_url': 'https://api.spotify.com/v1/artists/272ArH9SUAlslQqsSgPJA2'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '4rzfv0JLZfVhOhbSQ8o5jZ',
#   'song_name': 'Api',
#   'duration_ms': 376000,
#   'url': 'https://open.spotify.com/track/4rzfv0JLZfVhOhbSQ8o5jZ',
#   'popularity': 1,
#   'song_added': '2015-01-15T12:39:22Z',
#   'album_id': '2pANdqPvxInB0YvcDiw4ko',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '5o3jMYOSbaVz3tkgwhELSV',
#   'song_name': 'Is',
#   'duration_ms': 730066,
#   'url': 'https://open.spotify.com/track/5o3jMYOSbaVz3tkgwhELSV',
#   'popularity': 0,
#   'song_added': '2015-01-15T12:40:03Z',
#   'album_id': '6nlfkk5GoXRL1nktlATNsy',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '4Cy0NHJ8Gh0xMdwyM9RkQm',
#   'song_name': 'All I Want',
#   'duration_ms': 401440,
#   'url': 'https://open.spotify.com/track/4Cy0NHJ8Gh0xMdwyM9RkQm',
#   'popularity': 48,
#   'song_added': '2015-01-15T12:22:30Z',
#   'album_id': '4hnqM0JK4CM1phwfq1Ldyz',
#   'artist_id': '066X20Nz7iquqkkCW6Jxy6'},
#  {'song_id': '6hvFrZNocdt2FcKGCSY5NI',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df
# Out:
#                  album_id                                         album_name  \
# 0  2pANdqPvxInB0YvcDiw4ko                 Progressive Psy Trance Picks Vol.8
# 1  6nlfkk5GoXRL1nktlATNsy                         Wellness & Dreaming Source
# 2  4hnqM0JK4CM1phwfq1Ldyz                                  This Is Happening
# 3  2usKFntxa98WHMcyW6xJBz  Glenn Horiuchi Trio / Gelenn Horiuchi Quartet:...
# 4  0ivM6kSawaug0j3tZVusG2                     All The Best (Spanish Version)
#
#   album_release_date  album_total_tracks  \
# 0         2012-04-02                  20
# 1         2015-01-09                  25
# 2         2010-05-17                   9
# 3         2011-04-01                   8
# 4         2007-01-01                  18
#
#                                            album_url
# 0  https://open.spotify.com/album/2pANdqPvxInB0Yv...
# 1  https://open.spotify.com/album/6nlfkk5GoXRL1nk...
# 2  https://open.spotify.com/album/4hnqM0JK4CM1phw...
# ...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df
# Out:
#                 artist_id          artist_name  \
# 0  6eSdhw46riw2OUHgMwR8B5               Odiseo
# 1  5VQE4WOzPu9h3HnGLuBoA6         Vlasta Marek
# 2  066X20Nz7iquqkkCW6Jxy6      LCD Soundsystem
# 3  272ArH9SUAlslQqsSgPJA2  Glenn Horiuchi Trio
# 4  2KftmGt9sk1yLjsAoloC3M             Zucchero
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6eSdhw46riw...
# 1  https://api.spotify.com/v1/artists/5VQE4WOzPu9...
# 2  https://api.spotify.com/v1/artists/066X20Nz7iq...
# 3  https://api.spotify.com/v1/artists/272ArH9SUAl...
# 4  https://api.spotify.com/v1/artists/2KftmGt9sk1...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df
# Out:
#                   song_id             song_name  duration_ms  \
# 0  4rzfv0JLZfVhOhbSQ8o5jZ                   Api       376000
# 1  5o3jMYOSbaVz3tkgwhELSV                    Is       730066
# 2  4Cy0NHJ8Gh0xMdwyM9RkQm            All I Want       401440
# 3  6hvFrZNocdt2FcKGCSY5NI             Endpoints       358760
# 4  2E2znCPaS8anQe21GLxcvJ  You Are So Beautiful       176093
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4rzfv0JLZfVhOhb...           1
# 1  https://open.spotify.com/track/5o3jMYOSbaVz3tk...           0
# 2  https://open.spotify.com/track/4Cy0NHJ8Gh0xMdw...          48
# 3  https://open.spotify.com/track/6hvFrZNocdt2FcK...           0
# 4  https://open.spotify.com/track/2E2znCPaS8anQe2...           0
#
#              song_added                album_id               artist_id
# 0  2015-01-15T12:39:22Z  2pANdqPvxInB0YvcDiw4ko  0LyfQWJT6nXafLPZqxe9Of
# ...

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
album_df
# Out:
#                  album_id                                         album_name  \
# 0  2pANdqPvxInB0YvcDiw4ko                 Progressive Psy Trance Picks Vol.8
# 1  6nlfkk5GoXRL1nktlATNsy                         Wellness & Dreaming Source
# 2  4hnqM0JK4CM1phwfq1Ldyz                                  This Is Happening
# 3  2usKFntxa98WHMcyW6xJBz  Glenn Horiuchi Trio / Gelenn Horiuchi Quartet:...
# 4  0ivM6kSawaug0j3tZVusG2                     All The Best (Spanish Version)
#
#   album_release_date  album_total_tracks  \
# 0         2012-04-02                  20
# 1         2015-01-09                  25
# 2         2010-05-17                   9
# 3         2011-04-01                   8
# 4         2007-01-01                  18
#
#                                            album_url
# 0  https://open.spotify.com/album/2pANdqPvxInB0Yv...
# 1  https://open.spotify.com/album/6nlfkk5GoXRL1nk...
# 2  https://open.spotify.com/album/4hnqM0JK4CM1phw...
# ...

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            5 non-null      object
#  1   album_name          5 non-null      object
#  2   album_release_date  5 non-null      datetime64[ns]
#  3   album_total_tracks  5 non-null      int64
#  4   album_url           5 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
artist_df
# Out:
#                 artist_id          artist_name  \
# 0  6eSdhw46riw2OUHgMwR8B5               Odiseo
# 1  5VQE4WOzPu9h3HnGLuBoA6         Vlasta Marek
# 2  066X20Nz7iquqkkCW6Jxy6      LCD Soundsystem
# 3  272ArH9SUAlslQqsSgPJA2  Glenn Horiuchi Trio
# 4  2KftmGt9sk1yLjsAoloC3M             Zucchero
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6eSdhw46riw...
# 1  https://api.spotify.com/v1/artists/5VQE4WOzPu9...
# 2  https://api.spotify.com/v1/artists/066X20Nz7iq...
# 3  https://api.spotify.com/v1/artists/272ArH9SUAl...
# 4  https://api.spotify.com/v1/artists/2KftmGt9sk1...

# %%
song_df
# Out:
#                   song_id             song_name  duration_ms  \
# 0  4rzfv0JLZfVhOhbSQ8o5jZ                   Api       376000
# 1  5o3jMYOSbaVz3tkgwhELSV                    Is       730066
# 2  4Cy0NHJ8Gh0xMdwyM9RkQm            All I Want       401440
# 3  6hvFrZNocdt2FcKGCSY5NI             Endpoints       358760
# 4  2E2znCPaS8anQe21GLxcvJ  You Are So Beautiful       176093
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4rzfv0JLZfVhOhb...           1
# 1  https://open.spotify.com/track/5o3jMYOSbaVz3tk...           0
# 2  https://open.spotify.com/track/4Cy0NHJ8Gh0xMdw...          48
# 3  https://open.spotify.com/track/6hvFrZNocdt2FcK...           0
# 4  https://open.spotify.com/track/2E2znCPaS8anQe2...           0
#
#              song_added                album_id               artist_id
# 0  2015-01-15T12:39:22Z  2pANdqPvxInB0YvcDiw4ko  0LyfQWJT6nXafLPZqxe9Of
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      object
#  6   album_id     5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 452.0+ bytes

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             5 non-null      object
#  1   song_name           5 non-null      object
#  2   duration_ms         5 non-null      int64
#  3   url                 5 non-null      object
#  4   popularity          5 non-null      int64
#  5   song_added          5 non-null      datetime64[ns, UTC]
#  6   album_id            5 non-null      object
#  7   artist_id           5 non-null      object
#  8   album_release_date  5 non-null      datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](2), int64(2), object(5)
# memory usage: 492.0+ bytes
